# %% [markdown]
# <a href="https://colab.research.google.com/github/rregmi1993/Machine-Learning/blob/main/Statistics/Uniform_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd

# %%
uniform_data = stats.uniform.rvs(size = 10000, loc= 0, scale=10)

# %%
uniform_data
# Out:
# array([5.71751567, 1.85212733, 4.64962138, ..., 2.63282795, 1.44829463,
#        9.08783561])

# %%
data_df = pd.DataFrame(uniform_data)
data_df
# Out:
#              0
# 0     5.717516
# 1     1.852127
# 2     4.649621
# 3     8.256543
# 4     4.869278
# ...        ...
# 9995  3.770323
# 9996  2.403769
# 9997  2.632828
# 9998  1.448295
# 9999  9.087836
#
# [10000 rows x 1 columns]

# %%
data_df.plot(kind='density', xlim=(-1, 11))
# Out:
# <Axes: ylabel='Density'>
