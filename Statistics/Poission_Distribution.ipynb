# %% [markdown]
# <a href="https://colab.research.google.com/github/rregmi1993/Machine-Learning/blob/main/Statistics/Poission_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
sample = np.random.poisson(5, 10000)

# %%
sample
# Out:
# array([8, 7, 4, ..., 4, 4, 6])

# %%
plt.figure(figsize=(10, 10))
plt.hist(sample, bins=14, density=True)
plt.show()
